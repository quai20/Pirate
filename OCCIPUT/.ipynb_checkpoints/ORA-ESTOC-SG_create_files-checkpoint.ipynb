# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gsw

# %%
#LOAD DATASETS & VARIABLE TO INTERP
#ORAS4
ORA_T=xr.open_mfdataset('/home5/pharos/REFERENCE_DATA/OCEAN_REP/ORAS4/DATA/monthly_1x1/thetao_oras4_1m_200[5,6,7,8]_grid_1x1.nc')
ORA_S=xr.open_mfdataset('/home5/pharos/REFERENCE_DATA/OCEAN_REP/ORAS4/DATA/monthly_1x1/so_oras4_1m_200[5,6,7,8]_grid_1x1.nc')
ORA_T.thetao.load()
ORA_S.so.load()

#ESTOC
ESTOC_T=xr.open_mfdataset('/home5/pharos/REFERENCE_DATA/OCEAN_REP/ESTOC/DATA/200[5,6,7,8]/k7oda_tmp_*.nc',decode_times=False)
ESTOC_S=xr.open_mfdataset('/home5/pharos/REFERENCE_DATA/OCEAN_REP/ESTOC/DATA/200[5,6,7,8]/k7oda_sal_*.nc',decode_times=False)
#Handling date
date=np.empty(len(ESTOC_T.TIME.values),dtype='datetime64[D]')
for i in range(len(ESTOC_T.TIME.values)):
    Y=str(np.datetime64('1900')+ESTOC_T.TIME[i].values/12)
    Mi=(ESTOC_T.TIME[i].values % 12)+1
    if Mi<10:
        M='0'+str(Mi)
    else:
        M=str(Mi)
    date[i]=np.datetime64(Y+'-'+M+'-01','D')
ESTOC_T['TIME']=date
ESTOC_S['TIME']=date
ESTOC_T.TMP.load()
ESTOC_S.SAL.load()

# SG-SCRIPPS
SG_T=xr.open_mfdataset('/home5/pharos/REFERENCE_DATA/OCEAN_REP/SCRIPPS/200[5,6,7,8]/*_Temp_*.nc',decode_times=False)
SG_S=xr.open_mfdataset('/home5/pharos/REFERENCE_DATA/OCEAN_REP/SCRIPPS/200[5,6,7,8]/*_PSal_*.nc',decode_times=False)
#Handling date
date=np.empty(len(SG_T.TIME.values),dtype='datetime64[D]')
for i in range(len(SG_T.TIME.values)):
    Y=str(np.datetime64('2004')+int(SG_T.TIME[i].values/12))
    Mi=int((SG_T.TIME[i].values-0.5) % 12)+1
    if Mi<10:
        M='0'+str(Mi)
    else:
        M=str(Mi)
    date[i]=np.datetime64(Y+'-'+M+'-15','D')
SG_T['TIME']=date
SG_S['TIME']=date
SG_T.ARGO_TEMPERATURE_MEAN.load()
SG_S.ARGO_SALINITY_MEAN.load()

print 'loaded'

# %%
tifi=['200701','200702','200703','200704','200705','200706','200707','200708','200709','200710','200711','200712']

for ti in tifi:                
    DAT=xr.open_dataset('/export/home1/DATA/PIRATE/SDL_DATASETS/2007/'+ti+'_v1.nc')
    
    #INIT FINAL DATASET
    OCF= xr.Dataset({'STANDARD_LEVELS': (['N_LEVELS'],  DAT.STANDARD_LEVELS),
                    'JULD': (['N_OBS'], DAT.JULD),
                    'CYCLE_NUMBER': (['N_OBS'], DAT.CYCLE_NUMBER), 
                    'LONGITUDE': (['N_OBS'], DAT.LONGITUDE),
                    'LATITUDE': (['N_OBS'], DAT.LATITUDE),
                    'STATION_IDENTIFIER': (['N_OBS'], DAT.STATION_IDENTIFIER), 
                    'TEMP_OBS': (['N_OBS','N_LEVELS'], DAT.TEMP_OBS),
                    'PSAL_OBS': (['N_OBS','N_LEVELS'], DAT.PSAL_OBS),
                    'POTM_OBS': (['N_OBS','N_LEVELS'], DAT.POTM_OBS), 
                    'POTM_Hx': (['N_MEMBER','N_OBS','N_LEVELS'], DAT.POTM_Hx), 
                    'PSAL_Hx': (['N_MEMBER','N_OBS','N_LEVELS'], DAT.PSAL_Hx), 
                    'POTM_OTH': (['N_DATASET','N_OBS','N_LEVELS'], np.zeros([5,len(DAT.N_OBS),299])),                
                    'PSAL_OTH': (['N_DATASET','N_OBS','N_LEVELS'], np.zeros([5,len(DAT.N_OBS),299])),                                     
                    'DATASETS': (['N_DATASET'], ['ISAS15','MIT-ECCO','ORAS4','ESTOC','SG-SCRIPPS'])                
                    })
    
    OCF.POTM_OTH[0,:,:]=DAT.POTM_OTH[0,:,:] #REWRITE ISAS
    OCF.PSAL_OTH[0,:,:]=DAT.PSAL_OTH[0,:,:]
    OCF.POTM_OTH[1,:,:]=DAT.POTM_OTH[1,:,:] #REWRITE ECCO
    OCF.PSAL_OTH[1,:,:]=DAT.PSAL_OTH[1,:,:]    

    for i in DAT.N_OBS.values:    
        tio=pd.to_datetime(DAT.JULD[i].values,unit='D',origin=pd.to_datetime('1950/1/1'))
        lao=DAT.LATITUDE[i].values
        loo=DAT.LONGITUDE[i].values
        zio=DAT.STANDARD_LEVELS.values

        #ORAS4
        zio[0]=zio[0]-0.03  #SHIFT FIRST LEVEL FOR INTERPOLATION SUCCESS (CHEATING I KNOW...)
        INT_t=ORA_T.thetao.interp(time=tio, lat=lao, lon=np.mod(loo+360,360), depth=-zio)
        INT_s=ORA_S.so.interp(time=tio, lat=lao, lon=np.mod(loo+360,360), depth=-zio)
        OCF.POTM_OTH[2,i,:]=INT_t.values        
        OCF.PSAL_OTH[2,i,:]=INT_s.values

        #ESTOC    
        INX_t=ESTOC_T.TMP.interp(TIME=tio, LATITUDE=lao, LONGITUDE=np.mod(loo+360,360), DEPTH=-zio)
        INX_s=ESTOC_S.SAL.interp(TIME=tio, LATITUDE=lao, LONGITUDE=np.mod(loo+360,360), DEPTH=-zio)
        OCF.POTM_OTH[3,i,:]=INX_t.values        
        OCF.PSAL_OTH[3,i,:]=INX_s.values    

        #SG-SCRIPPS   
        pio=gsw.p_from_z(zio,lao)
        INY_t=SG_T.ARGO_TEMPERATURE_MEAN.interp(TIME=tio, LATITUDE=lao, LONGITUDE=np.mod(loo+360,360), PRESSURE=pio)
        INY_s=SG_S.ARGO_SALINITY_MEAN.interp(TIME=tio, LATITUDE=lao, LONGITUDE=np.mod(loo+360,360), PRESSURE=pio)
        SA=gsw.SA_from_SP(INY_s.values, pio, loo, lao)
        POTM=gsw.pt0_from_t(SA,INY_t.values,pio)
        OCF.POTM_OTH[4,i,:]=POTM
        OCF.PSAL_OTH[4,i,:]=INY_s.values         
        
    #WRITE
    OCF.to_netcdf('/export/home1/DATA/PIRATE/SDL_DATASETS/V2/2007/'+ti+'_v2.nc')
    print 'file wrote to /export/home1/DATA/PIRATE/SDL_DATASETS/V2/2007/'+ti+'_v2.nc'

# %%
OCF=xr.open_mfdataset('/export/home1/DATA/PIRATE/SDL_DATASETS/V2/2007/*.nc')
OCF
# Out:
# <xarray.Dataset>
# Dimensions:             (N_DATASET: 5, N_LEVELS: 299, N_MEMBER: 50, N_OBS: 1543)
# Dimensions without coordinates: N_DATASET, N_LEVELS, N_MEMBER, N_OBS
# Data variables:
#     STANDARD_LEVELS     (N_OBS, N_LEVELS) float64 dask.array<shape=(1543, 299), chunksize=(112, 299)>
#     POTM_Hx             (N_MEMBER, N_OBS, N_LEVELS) float64 dask.array<shape=(50, 1543, 299), chunksize=(50, 112, 299)>
#     JULD                (N_OBS) float64 dask.array<shape=(1543,), chunksize=(112,)>
#     LONGITUDE           (N_OBS) float64 dask.array<shape=(1543,), chunksize=(112,)>
#     TEMP_OBS            (N_OBS, N_LEVELS) float64 dask.array<shape=(1543, 299), chunksize=(112, 299)>
#     PSAL_OTH            (N_DATASET, N_OBS, N_LEVELS) float64 dask.array<shape=(5, 1543, 299), chunksize=(5, 112, 299)>
#     STATION_IDENTIFIER  (N_OBS) |S8 dask.array<shape=(1543,), chunksize=(112,)>
#     CYCLE_NUMBER        (N_OBS) float64 dask.array<shape=(1543,), chunksize=(112,)>
# ...

# %%
#detect doublons
sta=np.empty_like(OCF.N_OBS.values,dtype='S80')
for i in OCF.N_OBS.values:
    sta[i]=str(OCF.STATION_IDENTIFIER[i].values)+' '+str(OCF.JULD[i].values)+' '+str(OCF.LATITUDE[i].values)+' '+str(OCF.LONGITUDE[i].values)

from collections import Counter
[item for item, count in Counter(sta).iteritems() if count > 1]

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

import datetime
date_1 = datetime.datetime.strptime('01/01/1950', "%m/%d/%Y")

i1=402
i2=403
zio=np.arange(-5,-1500,-5)
plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
plt.plot(OCF.POTM_OBS[i1,:].values,zio,linewidth=1,label='OBS')
plt.plot(OCF.POTM_OBS[i2,:].values,zio,linewidth=1,label='OBS')
plt.subplot(1,2,2)
plt.plot(OCF.PSAL_OBS[i1,:].values,zio,linewidth=1,label='OBS')
plt.plot(OCF.PSAL_OBS[i2,:].values,zio,linewidth=1,label='OBS')
plt.suptitle(str(OCF.STATION_IDENTIFIER[i1].values)+' ## '+str(OCF.STATION_IDENTIFIER[i2].values)+'\n'+
             str(date_1 + datetime.timedelta(days=float(OCF.JULD[i1].values)))+' ## '+
             str(date_1 + datetime.timedelta(days=float(OCF.JULD[i2].values)))+'\n'+
             '{0:0.3f}'.format(OCF.LATITUDE[i1].values)+' / '+'{0:0.3f}'.format(OCF.LONGITUDE[i1].values)+' ## '+
             '{0:0.3f}'.format(OCF.LATITUDE[i2].values)+' / '+'{0:0.3f}'.format(OCF.LONGITUDE[i2].values)
                )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#GENERATE PDFs
import datetime
date_1 = datetime.datetime.strptime('01/01/1950', "%m/%d/%Y")
zio=np.arange(-5,-1500,-5)
for inz in [0]:#np.arange(0,len(OCF.N_OBS),1):
    print inz,
    plt.figure(figsize=(8,6))
    plt.subplot(1,2,1)
    plt.plot(OCF.POTM_OBS[inz,:].values,zio,linewidth=4,label='OBS')
    plt.plot(OCF.POTM_OTH[0,inz,:].values,zio,label='ISAS')
    plt.plot(OCF.POTM_OTH[1,inz,:].values,zio,label='ECCO')
    plt.plot(OCF.POTM_OTH[2,inz,:].values,zio,label='ORAS4')
    plt.plot(OCF.POTM_OTH[3,inz,:].values,zio,label='ESTOC')
    plt.plot(OCF.POTM_OTH[4,inz,:].values,zio,label='SCRIPPS')
    plt.fill_betweenx(zio,OCF.POTM_Hx[:,inz,:].min('N_MEMBER'),OCF.POTM_Hx[:,inz,:].max('N_MEMBER'),
                      facecolor='gray', alpha=0.3, label='OCCIPUT')
    plt.grid(linestyle=':')
    plt.legend(loc='lower right')
    plt.subplot(1,2,2)
    plt.plot(OCF.PSAL_OBS[inz,:].values,zio,linewidth=4,label='OBS')
    plt.plot(OCF.PSAL_OTH[0,inz,:].values,zio,label='ISAS')
    plt.plot(OCF.PSAL_OTH[1,inz,:].values,zio,label='ECCO')
    plt.plot(OCF.PSAL_OTH[2,inz,:].values,zio,label='ORAS4')
    plt.plot(OCF.PSAL_OTH[3,inz,:].values,zio,label='ESTOC')
    plt.plot(OCF.PSAL_OTH[4,inz,:].values,zio,label='SCRIPPS')
    plt.fill_betweenx(zio,OCF.PSAL_Hx[:,inz,:].min('N_MEMBER'),OCF.PSAL_Hx[:,inz,:].max('N_MEMBER'),
                      facecolor='gray', alpha=0.3, label='OCCIPUT')
    plt.grid(linestyle=':')
    plt.suptitle(str(OCF.STATION_IDENTIFIER[inz].values)+'\n'+
                 str(date_1 + datetime.timedelta(days=float(OCF.JULD[inz].values)))+'\n'+
                 '{0:0.3f}'.format(OCF.LATITUDE[inz].values)+' / '+'{0:0.3f}'.format(OCF.LONGITUDE[inz].values)
                )
    plt.show()
    #plt.savefig('/export/home1/DATA/PIRATE/SDL_DATASETS/V2/PNGs/OBS_'+'{0:04d}'.format(inz)+'.pdf')
    #plt.close()
# Out:
# 0
# <img src="data:image/png;base64,..." width="800">
