# %%
import xarray as xr
import pandas as pd
import numpy as np
from scipy import interpolate
import glob
import os
import gsw

def loop_on_file(path):
    
    #init output
    new_depth=np.arange(5,705,5)
    #init new dataset
    new_ds=xr.Dataset({'temp':(['N_PROF','DEPTH'],np.empty([0,len(new_depth)])*np.nan),
                   'latitude':(['N_PROF'],np.empty(0)),
                   'longitude':(['N_PROF'],np.empty(0)),
                   'juld':(['N_PROF'],np.empty(0)),
                   'platform_number':(['N_PROF'],np.empty(0)),
                   'wmo_inst_type':(['N_PROF'],np.empty(0)),
                   },
                   coords={'DEPTH':new_depth})   
    #go   
    DAT=xr.open_dataset(path,decode_times=False)
        
    #CHECK FOR PRES,DEPH,TEMP,PSAL
    varlist=DAT.keys()
    #KEEP WHAT WE NEED
    plus=['PLATFORM_NUMBER','CYCLE_NUMBER','WMO_INST_TYPE','JULD','JULD_QC','LATITUDE','LONGITUDE',
          'POSITION_QC','REFERENCE_DATE_TIME']
    if ('TEMP' in varlist):
        plus=np.append(plus,['TEMP','TEMP_QC','TEMP_ADJUSTED'])
    if ('PRES' in varlist):
        plus=np.append(plus,['PRES','PRES_QC','PRES_ADJUSTED'])    
    if ('DEPH' in varlist):
        plus=np.append(plus,['DEPH','DEPH_QC','DEPH_ADJUSTED'])    
    DAT=DAT[plus]
    #AREA
    #DAT=DAT.where((DAT.LATITUDE>=28)&(DAT.LATITUDE<=45)&(DAT.LONGITUDE>=-79)&(DAT.LONGITUDE<=-35),drop=True)
    DAT=DAT.where((DAT.LATITUDE>=22)&(DAT.LATITUDE<=45)&(DAT.LONGITUDE>=123)&(DAT.LONGITUDE<=170),drop=True)
    
    if(len(DAT.N_PROF.values)>0):    
        #GET VARLIST
        varlist=DAT.keys()
        #REDUCE TO QC=1
        mask1 = (np.abs(DAT['TEMP']) != np.nan) & (DAT['TEMP_QC'] == '1')
        mask2 = (DAT['JULD_QC'] == '1') & (DAT['POSITION_QC'] == '1')
        if ('DEPH' in varlist)&('PRES' in varlist):
            mask3=((np.abs(DAT['DEPH'])!=np.nan)|(np.abs(DAT['PRES'])!=np.nan))&((DAT['DEPH_QC']=='1')|(DAT['PRES_QC']=='1'))
        elif ('DEPH' in varlist):
            mask3=(np.abs(DAT['DEPH']) != np.nan) & (DAT['DEPH_QC'] == '1')
        elif ('PRES' in varlist):   
            mask3=(np.abs(DAT['PRES']) != np.nan) & (DAT['PRES_QC'] == '1')

        DAT = DAT.where(mask1 & mask2 & mask3, drop=True)

        if(len(DAT.N_PROF.values)>0):    
            #AT LEAST 10 POINTS ON PROFILE WITH MIN DEPTH =< 10m & MAX DEPHT >= 700m
            if ('DEPH' in varlist)&('PRES' in varlist):
                H = DAT['DEPH'].where(DAT['TEMP'].notnull()).max(dim='N_LEVELS')
                G = DAT['DEPH'].where(DAT['TEMP'].notnull()).min(dim='N_LEVELS')
                Hb = DAT['PRES'].where(DAT['TEMP'].notnull()).max(dim='N_LEVELS')
                Gb = DAT['PRES'].where(DAT['TEMP'].notnull()).min(dim='N_LEVELS')
                DAT = DAT.where(((H>=700)|(Hb>=710))&((G<=10)|(Gb<=10)),drop=True)    
            elif ('DEPH' in varlist):
                H = DAT['DEPH'].where(DAT['TEMP'].notnull()).max(dim='N_LEVELS')
                G = DAT['DEPH'].where(DAT['TEMP'].notnull()).min(dim='N_LEVELS')
                DAT = DAT.where((H>=700)&(G<=10),drop=True)    
            elif ('PRES' in varlist):   
                H = DAT['PRES'].where(DAT['TEMP'].notnull()).max(dim='N_LEVELS')
                G = DAT['PRES'].where(DAT['TEMP'].notnull()).min(dim='N_LEVELS')
                DAT = DAT.where((H>=710)&(G<=10),drop=True)

            M = DAT['TEMP'].notnull().sum('N_LEVELS')
            DAT = DAT.where((M>=10),drop=True) 

            #REDUCE DIMENSIONS
            DAT['A']=DAT['REFERENCE_DATE_TIME'].min(dim='N_LEVELS')
            DAT['C']=DAT['PLATFORM_NUMBER'].min(dim='N_LEVELS')
            DAT['D']=DAT['WMO_INST_TYPE'].min(dim='N_LEVELS')
            DAT['E']=DAT['CYCLE_NUMBER'].min(dim='N_LEVELS')
            DAT['F']=DAT['JULD'].min(dim='N_LEVELS')
            DAT['Fb']=DAT['JULD_QC'].min(dim='N_LEVELS')
            DAT['G']=DAT['LATITUDE'].min(dim='N_LEVELS')
            DAT['H']=DAT['LONGITUDE'].min(dim='N_LEVELS')
            DAT['I']=DAT['POSITION_QC'].min(dim='N_LEVELS')
            DAT=DAT.drop(['REFERENCE_DATE_TIME','PLATFORM_NUMBER','WMO_INST_TYPE','CYCLE_NUMBER',
                         'JULD','JULD_QC','LATITUDE','LONGITUDE','POSITION_QC'])
            DAT=DAT.rename({'A':'REFERENCE_DATE_TIME','C':'PLATFORM_NUMBER',
                            'D':'WMO_INST_TYPE','E':'DC_REFERENCE','F':'JULD','Fb':'JULD_QC','G':'LATITUDE',
                            'H':'LONGITUDE','I':'POSITION_QC'})
        
            if(len(DAT.N_PROF.values)>0):
                #KEEP ADJUSTED IF BETTER AND CALCULATE DEPTH WHEN PRES PROVIDED
                #CREATE DEPTH ARRAY
                DAT=DAT.assign(DEPTH = np.nan*DAT.TEMP)

                for i in DAT.N_PROF.values:
                    if (DAT.TEMP_ADJUSTED[i,:].notnull().sum('N_LEVELS')>=DAT.TEMP[i,:].notnull().sum('N_LEVELS')):
                        DAT.TEMP[i,:]=DAT.TEMP_ADJUSTED[i,:].values

                    if ('DEPH' in varlist)&('PRES' in varlist):
                        #ADJUSTED
                        if (DAT.DEPH_ADJUSTED[i,:].notnull().sum('N_LEVELS')>=DAT.DEPH[i,:].notnull().sum('N_LEVELS')):
                            DAT.DEPH[i,:]=DAT.DEPH_ADJUSTED[i,:].values
                        if (DAT.PRES_ADJUSTED[i,:].notnull().sum('N_LEVELS')>=DAT.PRES[i,:].notnull().sum('N_LEVELS')):
                            DAT.PRES[i,:]=DAT.PRES_ADJUSTED[i,:].values   
                        #CALCULATE DEPTH    
                        if (DAT.DEPH[i,:].notnull().sum('N_LEVELS')<DAT.PRES[i,:].notnull().sum('N_LEVELS')):
                            DAT.DEPTH[i,:]=gsw.z_from_p(DAT.PRES[0,:].values,DAT.LATITUDE[0])*-1    
                        else:
                            DAT.DEPTH[i,:]=DAT.DEPH[i,:]

                    elif ('DEPH' in varlist):
                        #ADJUSTED
                        if (DAT.DEPH_ADJUSTED[i,:].notnull().sum('N_LEVELS')>=DAT.DEPH[i,:].notnull().sum('N_LEVELS')):
                            DAT.DEPH[i,:]=DAT.DEPH_ADJUSTED[i,:].values
                        DAT.DEPTH[i,:]=DAT.DEPH[i,:]    
                    elif ('PRES' in varlist):   
                        #ADJUSTED
                        if (DAT.PRES_ADJUSTED[i,:].notnull().sum('N_LEVELS')>=DAT.PRES[i,:].notnull().sum('N_LEVELS')):
                            DAT.PRES[i,:]=DAT.PRES_ADJUSTED[i,:].values
                        #CALCULATE DEPTH                
                        DAT.DEPTH[i,:]=gsw.z_from_p(DAT.PRES[i,:].values,DAT.LATITUDE[i])*-1

                if ('PRES' in varlist):   
                    DAT=DAT.drop(['PRES','PRES_ADJUSTED','PRES_QC'])    
                if ('DEPH' in varlist):   
                    DAT=DAT.drop(['DEPH','DEPH_ADJUSTED','DEPH_QC'])    
                DAT=DAT.drop(['TEMP_ADJUSTED','TEMP_QC','JULD_QC','POSITION_QC'])    

                if(len(DAT.N_PROF.values)>0):    
                    #INTERPOLATION OF GOOD PROFILES
                    new_depth=np.arange(5,705,5)
                    #init new dataset
                    new_ds=xr.Dataset({'temp':(['N_PROF','DEPTH'],np.empty([len(DAT.N_PROF.values),len(new_depth)])*np.nan),
                                       'latitude':(['N_PROF'],DAT.LATITUDE.values),
                                       'longitude':(['N_PROF'],DAT.LONGITUDE.values),
                                       'juld':(['N_PROF'],DAT.JULD.values),
                                       'platform_number':(['N_PROF'],DAT.PLATFORM_NUMBER.values),
                                       'wmo_inst_type':(['N_PROF'],DAT.WMO_INST_TYPE.values),
                                      },
                                      coords={'DEPTH':new_depth})   
                    new_ds.attrs=DAT.attrs
                    new_ds.temp.attrs=DAT.TEMP.attrs
                    new_ds.latitude.attrs=DAT.LATITUDE.attrs
                    new_ds.longitude.attrs=DAT.LONGITUDE.attrs
                    new_ds.juld.attrs=DAT.JULD.attrs
                    new_ds.platform_number.attrs=DAT.PLATFORM_NUMBER.attrs
                    new_ds.wmo_inst_type.attrs=DAT.WMO_INST_TYPE.attrs                    

                    for i in DAT.N_PROF.values :
                        ccc=np.argwhere(~np.isnan(DAT.TEMP[i,:].values))                        
                        fnv=DAT.TEMP[i,ccc[0]].values
                        f=interpolate.interp1d(np.append(0,DAT.DEPTH[i,:].values),np.append(fnv,DAT.TEMP[i,:].values),
                                              kind='linear',bounds_error='False')
                        new_ds.temp[i,:]=f(new_depth)

    #OUT
    return new_ds

# %%
listyear=np.array(np.arange(1997,2018),dtype='S4')
for yeart in listyear:
    print yeart
    ROOT='/home/datawork-coriolis-cora-s/CORA_dataset/'
    path=glob.glob(os.path.join(ROOT+yeart+'/*_PR_*.nc'))
    path.sort()
    dsf=loop_on_file(path[0])
    for i in np.arange(1,len(path)):
        #LOGPLOT EVERY 20 FILES
        if(np.mod(i,30)==0):
            print path[i],' ...',i,'/',len(path)
        dsf=xr.concat([dsf,loop_on_file(path[i])],'N_PROF')
    dsf.to_netcdf('/export/home1/DATA/PIRATE/CORA/GulfStream/PROFILES/'+'CORA_SDL_GulfStream_TEMP_'+yeart+'.nc')
# Out:
# 1997
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970108_PR_BA.nc  ... 30 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970113_PR_TE.nc  ... 60 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970118_PR_IC.nc  ... 90 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970122_PR_IC.nc  ... 120 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970126_PR_ME.nc  ... 150 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970130_PR_OC.nc  ... 180 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970204_PR_BA.nc  ... 210 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970208_PR_OC.nc  ... 240 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970212_PR_TE.nc  ... 270 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970217_PR_OC.nc  ... 300 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970221_PR_OC.nc  ... 330 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970225_PR_XB.nc  ... 360 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970303_PR_OC.nc  ... 390 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970307_PR_XB.nc  ... 420 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970313_PR_OC.nc  ... 450 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970317_PR_TE.nc  ... 480 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970322_PR_IC.nc  ... 510 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970327_PR_PF.nc  ... 540 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970402_PR_SH.nc  ... 570 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970406_PR_TE.nc  ... 600 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970411_PR_SH.nc  ... 630 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970416_PR_ME.nc  ... 660 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970421_PR_SH.nc  ... 690 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970426_PR_SH.nc  ... 720 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970502_PR_OC.nc  ... 750 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970506_PR_XB.nc  ... 780 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970511_PR_PF.nc  ... 810 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970516_PR_OC.nc  ... 840 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970521_PR_ME.nc  ... 870 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970525_PR_XB.nc  ... 900 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970530_PR_SH.nc  ... 930 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970603_PR_OS.nc  ... 960 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970607_PR_ME.nc  ... 990 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970611_PR_BA.nc  ... 1020 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970615_PR_ME.nc  ... 1050 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970619_PR_OC.nc  ... 1080 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970623_PR_XB.nc  ... 1110 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970628_PR_BA.nc  ... 1140 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970702_PR_IC.nc  ... 1170 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970706_PR_ME.nc  ... 1200 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970710_PR_SH.nc  ... 1230 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970715_PR_OC.nc  ... 1260 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970719_PR_TE.nc  ... 1290 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970723_PR_OC.nc  ... 1320 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970727_PR_BA.nc  ... 1350 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970730_PR_TE.nc  ... 1380 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970803_PR_XB.nc  ... 1410 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970808_PR_BA.nc  ... 1440 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970811_PR_TE.nc  ... 1470 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970815_PR_ME.nc  ... 1500 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970819_PR_IC.nc  ... 1530 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970823_PR_BA.nc  ... 1560 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970826_PR_OS.nc  ... 1590 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970830_PR_IC.nc  ... 1620 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970902_PR_XB.nc  ... 1650 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970906_PR_SH.nc  ... 1680 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970910_PR_BA.nc  ... 1710 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970913_PR_IC.nc  ... 1740 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970916_PR_PF.nc  ... 1770 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970920_PR_BA.nc  ... 1800 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970923_PR_OC.nc  ... 1830 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970926_PR_TE.nc  ... 1860 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19970930_PR_SH.nc  ... 1890 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971004_PR_PF.nc  ... 1920 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971008_PR_OC.nc  ... 1950 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971012_PR_SH.nc  ... 1980 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971016_PR_IC.nc  ... 2010 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971019_PR_TE.nc  ... 2040 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971023_PR_PF.nc  ... 2070 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971027_PR_ME.nc  ... 2100 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971031_PR_ME.nc  ... 2130 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971104_PR_BA.nc  ... 2160 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971107_PR_TE.nc  ... 2190 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971111_PR_OC.nc  ... 2220 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971114_PR_SH.nc  ... 2250 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971118_PR_TE.nc  ... 2280 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971123_PR_ME.nc  ... 2310 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971127_PR_PF.nc  ... 2340 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971201_PR_TE.nc  ... 2370 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971205_PR_PF.nc  ... 2400 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971209_PR_ME.nc  ... 2430 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971213_PR_BA.nc  ... 2460 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971217_PR_BA.nc  ... 2490 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971221_PR_XB.nc  ... 2520 / 2578
# /home/datawork-coriolis-cora-s/CORA_dataset/1997/CO_DMQCGL01_19971227_PR_OC.nc  ... 2550 / 2578
# 1998
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980106_PR_ME.nc  ... 30 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980111_PR_BA.nc  ... 60 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980115_PR_TE.nc  ... 90 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980120_PR_OC.nc  ... 120 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980124_PR_OC.nc  ... 150 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980127_PR_XB.nc  ... 180 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980131_PR_SH.nc  ... 210 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980204_PR_SH.nc  ... 240 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980208_PR_PF.nc  ... 270 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980212_PR_IC.nc  ... 300 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980216_PR_ME.nc  ... 330 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980219_PR_XB.nc  ... 360 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980224_PR_OC.nc  ... 390 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980228_PR_SH.nc  ... 420 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980304_PR_PF.nc  ... 450 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980308_PR_SH.nc  ... 480 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980312_PR_XB.nc  ... 510 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980316_PR_TE.nc  ... 540 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980320_PR_SH.nc  ... 570 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980324_PR_TE.nc  ... 600 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980328_PR_TE.nc  ... 630 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980402_PR_IC.nc  ... 660 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980406_PR_OC.nc  ... 690 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980410_PR_OC.nc  ... 720 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980414_PR_XB.nc  ... 750 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980419_PR_BA.nc  ... 780 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980422_PR_XB.nc  ... 810 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980427_PR_BA.nc  ... 840 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980501_PR_ME.nc  ... 870 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980505_PR_IC.nc  ... 900 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980508_PR_XB.nc  ... 930 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980512_PR_SH.nc  ... 960 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980516_PR_SH.nc  ... 990 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980520_PR_SH.nc  ... 1020 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980525_PR_BA.nc  ... 1050 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980529_PR_BA.nc  ... 1080 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980602_PR_ME.nc  ... 1110 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980605_PR_SH.nc  ... 1140 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980609_PR_IC.nc  ... 1170 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980612_PR_XB.nc  ... 1200 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980616_PR_XB.nc  ... 1230 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980621_PR_OC.nc  ... 1260 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980625_PR_OS.nc  ... 1290 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980629_PR_ME.nc  ... 1320 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980703_PR_CD.nc  ... 1350 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980706_PR_TE.nc  ... 1380 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980710_PR_PF.nc  ... 1410 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980714_PR_IC.nc  ... 1440 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980717_PR_SH.nc  ... 1470 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980721_PR_BA.nc  ... 1500 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980724_PR_OS.nc  ... 1530 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980727_PR_XB.nc  ... 1560 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980731_PR_SH.nc  ... 1590 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980804_PR_TE.nc  ... 1620 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980808_PR_BA.nc  ... 1650 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980811_PR_SH.nc  ... 1680 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980815_PR_BA.nc  ... 1710 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980818_PR_SH.nc  ... 1740 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980821_PR_XB.nc  ... 1770 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980825_PR_ME.nc  ... 1800 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980828_PR_OC.nc  ... 1830 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980901_PR_IC.nc  ... 1860 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980904_PR_XB.nc  ... 1890 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980908_PR_SH.nc  ... 1920 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980912_PR_SH.nc  ... 1950 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980916_PR_PF.nc  ... 1980 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980920_PR_PF.nc  ... 2010 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980923_PR_SH.nc  ... 2040 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19980926_PR_XB.nc  ... 2070 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981001_PR_IC.nc  ... 2100 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981005_PR_ME.nc  ... 2130 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981009_PR_ME.nc  ... 2160 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981013_PR_OC.nc  ... 2190 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981018_PR_ME.nc  ... 2220 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981022_PR_BA.nc  ... 2250 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981026_PR_BA.nc  ... 2280 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981030_PR_OC.nc  ... 2310 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981103_PR_TE.nc  ... 2340 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981107_PR_PF.nc  ... 2370 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981111_PR_ME.nc  ... 2400 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981114_PR_TE.nc  ... 2430 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981118_PR_CT.nc  ... 2460 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981121_PR_SH.nc  ... 2490 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981125_PR_SH.nc  ... 2520 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981130_PR_OC.nc  ... 2550 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981204_PR_TE.nc  ... 2580 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981209_PR_IC.nc  ... 2610 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981212_PR_TE.nc  ... 2640 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981217_PR_SH.nc  ... 2670 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981222_PR_SH.nc  ... 2700 / 2753
# /home/datawork-coriolis-cora-s/CORA_dataset/1998/CO_DMQCGL01_19981227_PR_TE.nc  ... 2730 / 2753
# 1999
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990106_PR_PF.nc  ... 30 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990111_PR_PF.nc  ... 60 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990115_PR_PF.nc  ... 90 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990119_PR_PF.nc  ... 120 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990123_PR_OC.nc  ... 150 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990127_PR_OC.nc  ... 180 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990131_PR_SH.nc  ... 210 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990204_PR_SH.nc  ... 240 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990208_PR_OS.nc  ... 270 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990212_PR_BA.nc  ... 300 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990216_PR_ME.nc  ... 330 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990220_PR_ME.nc  ... 360 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990223_PR_TE.nc  ... 390 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990227_PR_PF.nc  ... 420 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990303_PR_TE.nc  ... 450 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990308_PR_BA.nc  ... 480 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990313_PR_BA.nc  ... 510 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990317_PR_OC.nc  ... 540 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990321_PR_ME.nc  ... 570 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990325_PR_BA.nc  ... 600 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990328_PR_OS.nc  ... 630 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990401_PR_SH.nc  ... 660 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990406_PR_OC.nc  ... 690 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990410_PR_ME.nc  ... 720 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990414_PR_PF.nc  ... 750 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990418_PR_SH.nc  ... 780 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990422_PR_SH.nc  ... 810 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990426_PR_TE.nc  ... 840 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990501_PR_ME.nc  ... 870 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990505_PR_SH.nc  ... 900 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990510_PR_OC.nc  ... 930 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990515_PR_BA.nc  ... 960 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990519_PR_BA.nc  ... 990 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990523_PR_SH.nc  ... 1020 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990527_PR_TE.nc  ... 1050 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990531_PR_TE.nc  ... 1080 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990604_PR_PF.nc  ... 1110 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990608_PR_TE.nc  ... 1140 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990612_PR_TE.nc  ... 1170 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990616_PR_ME.nc  ... 1200 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990621_PR_BA.nc  ... 1230 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990625_PR_SH.nc  ... 1260 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990630_PR_PF.nc  ... 1290 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990705_PR_OS.nc  ... 1320 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990708_PR_UD.nc  ... 1350 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990712_PR_ME.nc  ... 1380 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990716_PR_OC.nc  ... 1410 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990720_PR_BA.nc  ... 1440 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990723_PR_ME.nc  ... 1470 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990726_PR_SH.nc  ... 1500 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990730_PR_BA.nc  ... 1530 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990802_PR_XB.nc  ... 1560 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990806_PR_ME.nc  ... 1590 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990809_PR_SH.nc  ... 1620 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990813_PR_ME.nc  ... 1650 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990817_PR_OC.nc  ... 1680 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990821_PR_IC.nc  ... 1710 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990824_PR_OC.nc  ... 1740 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990827_PR_SH.nc  ... 1770 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990831_PR_PF.nc  ... 1800 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990904_PR_SH.nc  ... 1830 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990908_PR_SH.nc  ... 1860 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990912_PR_SH.nc  ... 1890 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990916_PR_IC.nc  ... 1920 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990919_PR_TE.nc  ... 1950 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990923_PR_XB.nc  ... 1980 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19990928_PR_BA.nc  ... 2010 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991001_PR_TE.nc  ... 2040 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991005_PR_XB.nc  ... 2070 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991010_PR_PF.nc  ... 2100 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991014_PR_PF.nc  ... 2130 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991018_PR_SH.nc  ... 2160 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991022_PR_TE.nc  ... 2190 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991026_PR_SH.nc  ... 2220 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991030_PR_PF.nc  ... 2250 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991103_PR_TE.nc  ... 2280 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991108_PR_BA.nc  ... 2310 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991112_PR_IC.nc  ... 2340 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991116_PR_BA.nc  ... 2370 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991120_PR_CT.nc  ... 2400 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991123_PR_OC.nc  ... 2430 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991126_PR_OC.nc  ... 2460 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991130_PR_BA.nc  ... 2490 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991204_PR_BA.nc  ... 2520 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991207_PR_XB.nc  ... 2550 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991211_PR_SH.nc  ... 2580 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991214_PR_XB.nc  ... 2610 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991218_PR_OC.nc  ... 2640 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991223_PR_BA.nc  ... 2670 / 2719
# /home/datawork-coriolis-cora-s/CORA_dataset/1999/CO_DMQCGL01_19991228_PR_TE.nc  ... 2700 / 2719
# 2000
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000105_PR_XB.nc  ... 30 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000110_PR_TE.nc  ... 60 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000115_PR_BA.nc  ... 90 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000118_PR_XB.nc  ... 120 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000123_PR_PF.nc  ... 150 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000128_PR_BA.nc  ... 180 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000131_PR_TE.nc  ... 210 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000204_PR_OC.nc  ... 240 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000208_PR_ME.nc  ... 270 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000211_PR_XB.nc  ... 300 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000215_PR_SH.nc  ... 330 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000219_PR_OC.nc  ... 360 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000222_PR_XB.nc  ... 390 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000226_PR_ME.nc  ... 420 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000229_PR_XB.nc  ... 450 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000304_PR_TE.nc  ... 480 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000308_PR_SH.nc  ... 510 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000312_PR_TE.nc  ... 540 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000316_PR_TE.nc  ... 570 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000321_PR_OC.nc  ... 600 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000325_PR_OS.nc  ... 630 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000329_PR_BA.nc  ... 660 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000402_PR_SH.nc  ... 690 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000407_PR_OC.nc  ... 720 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000411_PR_SH.nc  ... 750 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000415_PR_TE.nc  ... 780 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000419_PR_SH.nc  ... 810 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000423_PR_PF.nc  ... 840 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000427_PR_OC.nc  ... 870 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000501_PR_ME.nc  ... 900 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000505_PR_BA.nc  ... 930 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000509_PR_ME.nc  ... 960 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000513_PR_BA.nc  ... 990 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000516_PR_XB.nc  ... 1020 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000520_PR_SH.nc  ... 1050 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000524_PR_TE.nc  ... 1080 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000528_PR_SH.nc  ... 1110 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000602_PR_BA.nc  ... 1140 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000606_PR_PF.nc  ... 1170 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000610_PR_OC.nc  ... 1200 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000614_PR_OC.nc  ... 1230 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000617_PR_SH.nc  ... 1260 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000622_PR_OC.nc  ... 1290 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000626_PR_XB.nc  ... 1320 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000701_PR_OC.nc  ... 1350 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000705_PR_PF.nc  ... 1380 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000709_PR_OS.nc  ... 1410 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000712_PR_UD.nc  ... 1440 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000716_PR_OC.nc  ... 1470 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000719_PR_XB.nc  ... 1500 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000724_PR_OC.nc  ... 1530 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000728_PR_SH.nc  ... 1560 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000801_PR_SH.nc  ... 1590 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000806_PR_BA.nc  ... 1620 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000809_PR_TE.nc  ... 1650 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000813_PR_ME.nc  ... 1680 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000817_PR_OC.nc  ... 1710 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000821_PR_SH.nc  ... 1740 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000825_PR_XB.nc  ... 1770 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000829_PR_TE.nc  ... 1800 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000902_PR_OS.nc  ... 1830 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000906_PR_SH.nc  ... 1860 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000910_PR_UD.nc  ... 1890 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000914_PR_ME.nc  ... 1920 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000918_PR_CT.nc  ... 1950 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000922_PR_OC.nc  ... 1980 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000926_PR_OS.nc  ... 2010 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20000930_PR_OC.nc  ... 2040 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001004_PR_OC.nc  ... 2070 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001008_PR_ME.nc  ... 2100 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001012_PR_PF.nc  ... 2130 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001016_PR_SH.nc  ... 2160 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001021_PR_ME.nc  ... 2190 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001025_PR_OS.nc  ... 2220 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001029_PR_SH.nc  ... 2250 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001102_PR_XB.nc  ... 2280 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001107_PR_OC.nc  ... 2310 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001111_PR_IC.nc  ... 2340 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001114_PR_XB.nc  ... 2370 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001119_PR_IC.nc  ... 2400 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001122_PR_XB.nc  ... 2430 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001126_PR_XB.nc  ... 2460 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001130_PR_TE.nc  ... 2490 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001205_PR_OS.nc  ... 2520 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001208_PR_XB.nc  ... 2550 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001213_PR_OC.nc  ... 2580 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001217_PR_SH.nc  ... 2610 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001222_PR_SH.nc  ... 2640 / 2698
# /home/datawork-coriolis-cora-s/CORA_dataset/2000/CO_DMQCGL01_20001227_PR_SH.nc  ... 2670 / 2698
# 2001
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010105_PR_XB.nc  ... 30 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010110_PR_BA.nc  ... 60 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010114_PR_TE.nc  ... 90 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010118_PR_TE.nc  ... 120 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010122_PR_XB.nc  ... 150 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010126_PR_SH.nc  ... 180 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010131_PR_BO.nc  ... 210 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010204_PR_CT.nc  ... 240 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010208_PR_CD.nc  ... 270 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010211_PR_OC.nc  ... 300 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010214_PR_ME.nc  ... 330 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010217_PR_PF.nc  ... 360 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010220_PR_SH.nc  ... 390 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010223_PR_SH.nc  ... 420 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010227_PR_OC.nc  ... 450 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010302_PR_TE.nc  ... 480 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010306_PR_SH.nc  ... 510 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010310_PR_PF.nc  ... 540 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010314_PR_OC.nc  ... 570 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010318_PR_OC.nc  ... 600 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010321_PR_TE.nc  ... 630 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010325_PR_XB.nc  ... 660 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010329_PR_BA.nc  ... 690 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010401_PR_TE.nc  ... 720 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010405_PR_OC.nc  ... 750 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010409_PR_BA.nc  ... 780 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010413_PR_BA.nc  ... 810 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010416_PR_XB.nc  ... 840 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010419_PR_TE.nc  ... 870 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010423_PR_BA.nc  ... 900 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010426_PR_OS.nc  ... 930 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010429_PR_TE.nc  ... 960 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010502_PR_TE.nc  ... 990 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010506_PR_OC.nc  ... 1020 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010509_PR_ME.nc  ... 1050 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010512_PR_XB.nc  ... 1080 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010516_PR_BO.nc  ... 1110 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010519_PR_PF.nc  ... 1140 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010522_PR_TE.nc  ... 1170 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010525_PR_SH.nc  ... 1200 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010528_PR_XB.nc  ... 1230 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010601_PR_BA.nc  ... 1260 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010604_PR_OC.nc  ... 1290 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010608_PR_BA.nc  ... 1320 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010612_PR_BO.nc  ... 1350 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010615_PR_SH.nc  ... 1380 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010619_PR_BA.nc  ... 1410 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010622_PR_XB.nc  ... 1440 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010626_PR_SH.nc  ... 1470 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010630_PR_OC.nc  ... 1500 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010704_PR_BO.nc  ... 1530 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010707_PR_BO.nc  ... 1560 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010710_PR_OS.nc  ... 1590 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010713_PR_OC.nc  ... 1620 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010716_PR_TE.nc  ... 1650 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010720_PR_BA.nc  ... 1680 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010723_PR_SH.nc  ... 1710 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010726_PR_XB.nc  ... 1740 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010730_PR_OC.nc  ... 1770 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010802_PR_TE.nc  ... 1800 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010805_PR_XC.nc  ... 1830 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010809_PR_XB.nc  ... 1860 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010813_PR_PF.nc  ... 1890 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010817_PR_OC.nc  ... 1920 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010820_PR_TE.nc  ... 1950 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010824_PR_XC.nc  ... 1980 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010828_PR_ME.nc  ... 2010 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010831_PR_OC.nc  ... 2040 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010903_PR_SH.nc  ... 2070 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010906_PR_PF.nc  ... 2100 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010909_PR_SH.nc  ... 2130 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010912_PR_SH.nc  ... 2160 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010916_PR_BA.nc  ... 2190 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010919_PR_BO.nc  ... 2220 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010922_PR_IC.nc  ... 2250 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010925_PR_ME.nc  ... 2280 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20010928_PR_ME.nc  ... 2310 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011001_PR_OC.nc  ... 2340 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011004_PR_OS.nc  ... 2370 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011008_PR_BA.nc  ... 2400 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011011_PR_DT.nc  ... 2430 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011015_PR_BA.nc  ... 2460 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011018_PR_PF.nc  ... 2490 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011021_PR_TE.nc  ... 2520 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011025_PR_ME.nc  ... 2550 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011028_PR_TE.nc  ... 2580 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011101_PR_ME.nc  ... 2610 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011104_PR_XC.nc  ... 2640 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011108_PR_TE.nc  ... 2670 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011112_PR_SH.nc  ... 2700 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011115_PR_XB.nc  ... 2730 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011119_PR_PF.nc  ... 2760 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011122_PR_XC.nc  ... 2790 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011126_PR_XB.nc  ... 2820 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011130_PR_BA.nc  ... 2850 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011203_PR_XB.nc  ... 2880 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011207_PR_DT.nc  ... 2910 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011210_PR_TE.nc  ... 2940 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011214_PR_ME.nc  ... 2970 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011218_PR_ME.nc  ... 3000 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011221_PR_XC.nc  ... 3030 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011226_PR_SH.nc  ... 3060 / 3097
# /home/datawork-coriolis-cora-s/CORA_dataset/2001/CO_DMQCGL01_20011230_PR_XB.nc  ... 3090 / 3097
# 2002
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020106_PR_BA.nc  ... 30 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020111_PR_BA.nc  ... 60 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020114_PR_XB.nc  ... 90 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020118_PR_OC.nc  ... 120 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020122_PR_IC.nc  ... 150 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020126_PR_ME.nc  ... 180 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020130_PR_OC.nc  ... 210 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020203_PR_SH.nc  ... 240 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020207_PR_PF.nc  ... 270 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020211_PR_XB.nc  ... 300 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020215_PR_SH.nc  ... 330 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020219_PR_ME.nc  ... 360 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020222_PR_PF.nc  ... 390 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020226_PR_IC.nc  ... 420 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020301_PR_XB.nc  ... 450 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020305_PR_TE.nc  ... 480 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020310_PR_BA.nc  ... 510 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020314_PR_BA.nc  ... 540 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020317_PR_XB.nc  ... 570 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020321_PR_OC.nc  ... 600 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020324_PR_SH.nc  ... 630 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020328_PR_OC.nc  ... 660 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020401_PR_PF.nc  ... 690 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020405_PR_BO.nc  ... 720 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020408_PR_TE.nc  ... 750 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020412_PR_PF.nc  ... 780 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020416_PR_BO.nc  ... 810 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020419_PR_OS.nc  ... 840 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020423_PR_OC.nc  ... 870 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020427_PR_BO.nc  ... 900 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020430_PR_XB.nc  ... 930 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020504_PR_PF.nc  ... 960 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020508_PR_ME.nc  ... 990 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020511_PR_XB.nc  ... 1020 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020515_PR_OC.nc  ... 1050 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020518_PR_OS.nc  ... 1080 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020522_PR_ME.nc  ... 1110 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020526_PR_IC.nc  ... 1140 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020530_PR_BA.nc  ... 1170 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020603_PR_ME.nc  ... 1200 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020607_PR_OC.nc  ... 1230 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020611_PR_OS.nc  ... 1260 / 2668
# /home/datawork-coriolis-cora-s/CORA_dataset/2002/CO_DMQCGL01_20020614_PR_XB.nc  ... 1290 / 2668
# ...
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160624_PR_CT.nc  ... 1740 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160627_PR_CT.nc  ... 1770 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160630_PR_BA.nc  ... 1800 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160703_PR_CT.nc  ... 1830 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160706_PR_ME.nc  ... 1860 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160709_PR_CT.nc  ... 1890 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160711_PR_TE.nc  ... 1920 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160714_PR_RE.nc  ... 1950 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160717_PR_RE.nc  ... 1980 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160720_PR_RE.nc  ... 2010 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160723_PR_OS.nc  ... 2040 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160726_PR_CT.nc  ... 2070 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160729_PR_BA.nc  ... 2100 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160801_PR_OS.nc  ... 2130 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160804_PR_SM.nc  ... 2160 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160808_PR_BA.nc  ... 2190 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160811_PR_RE.nc  ... 2220 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160815_PR_IC.nc  ... 2250 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160819_PR_BA.nc  ... 2280 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160823_PR_BA.nc  ... 2310 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160827_PR_BA.nc  ... 2340 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160831_PR_BA.nc  ... 2370 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160903_PR_PF.nc  ... 2400 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160906_PR_TE.nc  ... 2430 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160910_PR_GL.nc  ... 2460 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160913_PR_OS.nc  ... 2490 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160916_PR_RE.nc  ... 2520 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160919_PR_TE.nc  ... 2550 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160923_PR_CT.nc  ... 2580 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160926_PR_CT.nc  ... 2610 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20160929_PR_BA.nc  ... 2640 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161002_PR_GL.nc  ... 2670 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161005_PR_GL.nc  ... 2700 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161008_PR_GL.nc  ... 2730 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161011_PR_PF.nc  ... 2760 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161014_PR_SM.nc  ... 2790 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161018_PR_BA.nc  ... 2820 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161021_PR_GL.nc  ... 2850 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161024_PR_PF.nc  ... 2880 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161027_PR_SM.nc  ... 2910 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161030_PR_XB.nc  ... 2940 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161103_PR_OS.nc  ... 2970 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161106_PR_SM.nc  ... 3000 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161110_PR_BA.nc  ... 3030 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161113_PR_RE.nc  ... 3060 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161116_PR_OC.nc  ... 3090 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161119_PR_ME.nc  ... 3120 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161122_PR_BA.nc  ... 3150 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161125_PR_CT.nc  ... 3180 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161128_PR_GL.nc  ... 3210 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161201_PR_GL.nc  ... 3240 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161203_PR_XB.nc  ... 3270 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161206_PR_RE.nc  ... 3300 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161209_PR_OS.nc  ... 3330 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161213_PR_BA.nc  ... 3360 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161216_PR_RE.nc  ... 3390 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161219_PR_XB.nc  ... 3420 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161223_PR_RE.nc  ... 3450 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161227_PR_PF.nc  ... 3480 / 3518
# /home/datawork-coriolis-cora-s/CORA_dataset/2016/CO_DMQCGL01_20161231_PR_CT.nc  ... 3510 / 3518
# 2017
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170104_PR_RE.nc  ... 30 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170108_PR_CT.nc  ... 60 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170111_PR_OS.nc  ... 90 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170115_PR_BA.nc  ... 120 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170118_PR_CT.nc  ... 150 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170121_PR_CT.nc  ... 180 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170123_PR_TE.nc  ... 210 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170126_PR_PF.nc  ... 240 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170129_PR_ME.nc  ... 270 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170201_PR_BA.nc  ... 300 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170203_PR_TE.nc  ... 330 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170206_PR_TE.nc  ... 360 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170209_PR_PF.nc  ... 390 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170212_PR_TE.nc  ... 420 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170216_PR_BA.nc  ... 450 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170219_PR_RE.nc  ... 480 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170223_PR_OC.nc  ... 510 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170226_PR_SM.nc  ... 540 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170301_PR_RE.nc  ... 570 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170304_PR_OS.nc  ... 600 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170307_PR_OS.nc  ... 630 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170310_PR_GL.nc  ... 660 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170313_PR_CT.nc  ... 690 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170316_PR_GL.nc  ... 720 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170319_PR_ME.nc  ... 750 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170322_PR_OS.nc  ... 780 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170325_PR_OC.nc  ... 810 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170328_PR_OC.nc  ... 840 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170331_PR_RE.nc  ... 870 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170403_PR_TE.nc  ... 900 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170406_PR_XB.nc  ... 930 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170410_PR_CT.nc  ... 960 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170413_PR_CT.nc  ... 990 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170416_PR_GL.nc  ... 1020 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170419_PR_OS.nc  ... 1050 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170422_PR_OS.nc  ... 1080 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170425_PR_PF.nc  ... 1110 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170428_PR_TE.nc  ... 1140 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170502_PR_GL.nc  ... 1170 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170505_PR_OC.nc  ... 1200 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170508_PR_OC.nc  ... 1230 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170511_PR_RE.nc  ... 1260 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170514_PR_TE.nc  ... 1290 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170517_PR_TE.nc  ... 1320 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170521_PR_BA.nc  ... 1350 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170524_PR_GL.nc  ... 1380 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170527_PR_OC.nc  ... 1410 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170530_PR_ME.nc  ... 1440 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170602_PR_GL.nc  ... 1470 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170605_PR_CT.nc  ... 1500 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170608_PR_BA.nc  ... 1530 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170610_PR_XB.nc  ... 1560 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170613_PR_SM.nc  ... 1590 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170616_PR_RE.nc  ... 1620 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170619_PR_SM.nc  ... 1650 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170622_PR_TE.nc  ... 1680 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170626_PR_CT.nc  ... 1710 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170629_PR_PF.nc  ... 1740 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170703_PR_GL.nc  ... 1770 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170706_PR_OS.nc  ... 1800 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170709_PR_TE.nc  ... 1830 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170713_PR_OC.nc  ... 1860 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170716_PR_PF.nc  ... 1890 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170719_PR_OS.nc  ... 1920 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170722_PR_OS.nc  ... 1950 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170725_PR_RE.nc  ... 1980 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170728_PR_RE.nc  ... 2010 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170731_PR_PF.nc  ... 2040 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170803_PR_SM.nc  ... 2070 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170807_PR_CT.nc  ... 2100 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170810_PR_OS.nc  ... 2130 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170813_PR_TE.nc  ... 2160 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170817_PR_OC.nc  ... 2190 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170821_PR_BA.nc  ... 2220 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170825_PR_GL.nc  ... 2250 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170829_PR_GL.nc  ... 2280 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170901_PR_TE.nc  ... 2310 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170905_PR_OS.nc  ... 2340 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170908_PR_TE.nc  ... 2370 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170912_PR_OC.nc  ... 2400 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170915_PR_RE.nc  ... 2430 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170919_PR_CT.nc  ... 2460 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170922_PR_ME.nc  ... 2490 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170926_PR_GL.nc  ... 2520 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20170930_PR_BA.nc  ... 2550 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171003_PR_TE.nc  ... 2580 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171008_PR_GL.nc  ... 2610 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171011_PR_TE.nc  ... 2640 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171015_PR_CT.nc  ... 2670 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171018_PR_PF.nc  ... 2700 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171022_PR_GL.nc  ... 2730 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171026_PR_OS.nc  ... 2760 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171030_PR_OC.nc  ... 2790 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171103_PR_PF.nc  ... 2820 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171108_PR_GL.nc  ... 2850 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171112_PR_OS.nc  ... 2880 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171117_PR_OS.nc  ... 2910 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171121_PR_RE.nc  ... 2940 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171125_PR_TE.nc  ... 2970 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171130_PR_OS.nc  ... 3000 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171204_PR_XB.nc  ... 3030 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171209_PR_SM.nc  ... 3060 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171214_PR_RE.nc  ... 3090 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171219_PR_BA.nc  ... 3120 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171224_PR_BA.nc  ... 3150 / 3197
# /home/datawork-coriolis-cora-s/CORA_dataset/2017/CO_DMQCGL01_20171229_PR_OS.nc  ... 3180 / 3197

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
print len(dsf.N_PROF)
#MAP
fig=plt.figure(figsize=(22,6))
mproj=ccrs.PlateCarree()
az = fig.add_subplot(1, 1, 1, projection=mproj)
x.set_extent([-82, -30, 20, 50], crs=mproj)
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE, linewidth=0.5)
ax.set_xticks(range(-75,-30,10), crs=mproj)
ax.set_yticks(range(25,50,5), crs=mproj)
az.plot(dsf.longitude,dsf.latitude,'o',markersize=3)
#PROFILES
plt.figure(figsize=(18,6))
plt.pcolor(pd.to_datetime(dsf.juld.values,unit='D',origin=pd.to_datetime('1950/1/1')),
                          dsf.DEPTH,dsf.temp.transpose(),cmap='bwr',vmin=-5.,vmax=30.)
plt.gca().invert_yaxis()

plt.show()
# Out:
# 9594
